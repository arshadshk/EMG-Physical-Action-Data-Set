# %% [markdown]
# # ASSIGNMENT-4          ----ARSHAD SHAIKH----

# %%
import pandas as pd

# %%
file_path_S1N = ["C:\\Normalsub1\Bowing.txt",
"C:\\Normalsub1\Clapping.txt",
"C:\\Normalsub1\Handshaking.txt",
"C:\\Normalsub1\Hugging.txt",
"C:\\Normalsub1\Jumping.txt",
"C:\\Normalsub1\Running.txt",
"C:\\Normalsub1\Seating.txt",
"C:\\Normalsub1\Standing.txt",
"C:\\Normalsub1\Walking.txt",
"C:\\Normalsub1\Waving.txt" ] 


file_path_S2N = ["C:\\Normalsub2\Bowing.txt",
"C:\\Normalsub2\Clapping.txt",
"C:\\Normalsub2\Handshaking.txt",
"C:\\Normalsub2\Hugging.txt",
"C:\\Normalsub2\Jumping.txt",
"C:\\Normalsub2\Running.txt",
"C:\\Normalsub2\Seating.txt",
"C:\\Normalsub2\Standing.txt",
"C:\\Normalsub2\Walking.txt",
"C:\\Normalsub2\Waving.txt" ]

file_path_S3N = ["C:\\Normalsub3\Bowing.txt",
"C:\\Normalsub3\Clapping.txt",
"C:\\Normalsub3\Handshaking.txt",
"C:\\Normalsub3\Hugging.txt",
"C:\\Normalsub3\Jumping.txt",
"C:\\Normalsub3\Running.txt",
"C:\\Normalsub3\Seating.txt",
"C:\\Normalsub3\Standing.txt",
"C:\\Normalsub3\Walking.txt",
"C:\\Normalsub3\Waving.txt" ]

file_path_S4N = ["C:\\Normalsub4\Bowing.txt",
"C:\\Normalsub4\Clapping.txt",
"C:\\Normalsub4\Handshaking.txt",
"C:\\Normalsub4\Hugging.txt",
"C:\\Normalsub4\Jumping.txt",
"C:\\Normalsub4\Running.txt",
"C:\\Normalsub4\Seating.txt",
"C:\\Normalsub4\Standing.txt",
"C:\\Normalsub4\Walking.txt",
"C:\\Normalsub4\Waving.txt" ]

file_path_S1A =["C:\\Aggressivesub1\Elbowing.txt",
"C:\\Aggressivesub1\Frontkicking.txt",
"C:\\Aggressivesub1\Hamering.txt",
"C:\\Aggressivesub1\Headering.txt",
"C:\\Aggressivesub1\Kneeing.txt",
"C:\\Aggressivesub1\Pulling.txt",
"C:\\Aggressivesub1\Punching.txt",
"C:\\Aggressivesub1\Pushing.txt",
"C:\\Aggressivesub1\Sidekicking.txt",
"C:\\Aggressivesub1\Slapping.txt"]

file_path_S2A =["C:\\Aggressivesub2\Elbowing.txt",
"C:\\Aggressivesub2\Frontkicking.txt",
"C:\\Aggressivesub2\Hamering.txt",
"C:\\Aggressivesub2\Headering.txt",
"C:\\Aggressivesub2\Kneeing.txt",
"C:\\Aggressivesub2\Pulling.txt",
"C:\\Aggressivesub2\Punching.txt",
"C:\\Aggressivesub2\Pushing.txt",
"C:\\Aggressivesub2\Sidekicking.txt",
"C:\\Aggressivesub2\Slapping.txt"]

file_path_S3A =["C:\\Aggressivesub3\Elbowing.txt",
"C:\\Aggressivesub3\Frontkicking.txt",
"C:\\Aggressivesub3\Hamering.txt",
"C:\\Aggressivesub3\Headering.txt",
"C:\\Aggressivesub3\Kneeing.txt",
"C:\\Aggressivesub3\Pulling.txt",
"C:\\Aggressivesub3\Punching.txt",
"C:\\Aggressivesub3\Pushing.txt",
"C:\\Aggressivesub3\Sidekicking.txt",
"C:\\Aggressivesub3\Slapping.txt"]

file_path_S4A =["C:\\Aggressivesub4\Elbowing.txt",
"C:\\Aggressivesub4\Frontkicking.txt",
"C:\\Aggressivesub4\Hamering.txt",
"C:\\Aggressivesub4\Headering.txt",
"C:\\Aggressivesub4\Kneeing.txt",
"C:\\Aggressivesub4\Pulling.txt",
"C:\\Aggressivesub4\Punching.txt",
"C:\\Aggressivesub4\Pushing.txt",
"C:\\Aggressivesub4\Sidekicking.txt",
"C:\\Aggressivesub4\Slapping.txt"]

# %%
Fn_S1N = ['S1_N_Bowing',
'S1_N_Clapping',
'S1_N_Handshaking',
'S1_N_Hugging',
'S1_N_Jumping',
'S1_N_Running',
'S1_N_Seating',
'S1_N_Standing',
'S1_N_Walking',
'S1_N_Waving']

Fn_S2N = ['S2_N_Bowing',
'S2_N_Clapping',
'S2_N_Handshaking',
'S2_N_Hugging',
'S2_N_Jumping',
'S2_N_Running',
'S2_N_Seating',
'S2_N_Standing',
'S2_N_Walking',
'S2_N_Waving']

Fn_S3N = ['S3_N_Bowing',
'S3_N_Clapping',
'S3_N_Handshaking',
'S3_N_Hugging',
'S3_N_Jumping',
'S3_N_Running',
'S3_N_Seating',
'S3_N_Standing',
'S3_N_Walking',
'S3_N_Waving']

Fn_S4N = ['S4_N_Bowing',
'S4_N_Clapping',
'S4_N_Handshaking',
'S4_N_Hugging',
'S4_N_Jumping',
'S4_N_Running',
'S4_N_Seating',
'S4_N_Standing',
'S4_N_Walking',
'S4_N_Waving']

Fn_S1A=["S1_A_Elbowing",
"S1_A_Frontkicking",
"S1_A_Hamering",
"S1_A_Headering",
"S1_A_Kneeing",
"S1_A_Pulling",
"S1_A_Punching",
"S1_A_Pushing",
"S1_A_Sidekicking",
"S1_A_Slapping"]

Fn_S2A=["S2_A_Elbowing",
"S2_A_Frontkicking",
"S2_A_Hamering",
"S2_A_Headering",
"S2_A_Kneeing",
"S2_A_Pulling",
"S2_A_Punching",
"S2_A_Pushing",
"S2_A_Sidekicking",
"S2_A_Slapping"]

Fn_S3A=["S3_A_Elbowing",
"S3_A_Frontkicking",
"S3_A_Hamering",
"S3_A_Headering",
"S3_A_Kneeing",
"S3_A_Pulling",
"S3_A_Punching",
"S3_A_Pushing",
"S3_A_Sidekicking",
"S3_A_Slapping"]

Fn_S4A=["S4_A_Elbowing",
"S4_A_Frontkicking",
"S4_A_Hamering",
"S4_A_Headering",
"S4_A_Kneeing",
"S4_A_Pulling",
"S4_A_Punching",
"S4_A_Pushing",
"S4_A_Sidekicking",
"S4_A_Slapping"]

# %%
d_S1_N={}
d_S2_N={}
d_S3_N={}
d_S4_N={}

d_S1_A={}
d_S2_A={}
d_S3_A={}
d_S4_A={}

# %%
for path,name in zip(file_path_S1N,Fn_S1N):
    d_S1_N[name]= pd.read_csv (path,
                  delimiter='\t', 
                  names = ['ch1  R-bic', 'ch2 R-Tri 1' , 'ch3  L-Bic 2','ch4 L-Tri 3','ch5 R-Tri 4',
                           'ch6 R-Ham 5','ch7 L-Thi 6','ch8 L-Ham 7'])
for name,path in zip(Fn_S1A,file_path_S1A):
    d_S1_A[name]= pd.read_csv (path,
                  delimiter='\t', 
                  names = ['ch1  R-bic', 'ch2 R-Tri 1' , 'ch3  L-Bic 2','ch4 L-Tri 3','ch5 R-Tri 4',
                           'ch6 R-Ham 5','ch7 L-Thi 6','ch8 L-Ham 7'])
    
    
S1_N_Bowing = pd.DataFrame.from_dict(d_S1_N['S1_N_Bowing'])
S1_N_Clapping = pd.DataFrame.from_dict(d_S1_N['S1_N_Clapping'])
S1_N_Handshaking = pd.DataFrame.from_dict(d_S1_N['S1_N_Handshaking'])
S1_N_Hugging = pd.DataFrame.from_dict(d_S1_N['S1_N_Hugging'])
S1_N_Jumping = pd.DataFrame.from_dict(d_S1_N['S1_N_Jumping'])
S1_N_Running = pd.DataFrame.from_dict(d_S1_N['S1_N_Running'])
S1_N_Seating = pd.DataFrame.from_dict(d_S1_N['S1_N_Seating'])
S1_N_Standing = pd.DataFrame.from_dict(d_S1_N['S1_N_Standing'])
S1_N_Walking = pd.DataFrame.from_dict(d_S1_N['S1_N_Walking'])
S1_N_Waving = pd.DataFrame.from_dict(d_S1_N['S1_N_Waving'])


    
S1_A_Elbowing = pd.DataFrame.from_dict(d_S1_A["S1_A_Elbowing"])
S1_A_Frontkicking = pd.DataFrame.from_dict(d_S1_A["S1_A_Frontkicking"])
S1_A_Hamering = pd.DataFrame.from_dict(d_S1_A["S1_A_Hamering"])
S1_A_Headering = pd.DataFrame.from_dict(d_S1_A["S1_A_Headering"])
S1_A_Kneeing = pd.DataFrame.from_dict(d_S1_A["S1_A_Kneeing"])
S1_A_Pulling = pd.DataFrame.from_dict(d_S1_A["S1_A_Pulling"])
S1_A_Punching = pd.DataFrame.from_dict(d_S1_A["S1_A_Punching"])
S1_A_Pushing = pd.DataFrame.from_dict(d_S1_A["S1_A_Pushing"])
S1_A_Sidekicking = pd.DataFrame.from_dict(d_S1_A["S1_A_Sidekicking"])
S1_A_Slapping = pd.DataFrame.from_dict(d_S1_A["S1_A_Slapping"])

# %%
###########################################################################################################
###########################################################################################################

# %%
for path,name in zip(file_path_S2N,Fn_S2N):
    d_S2_N[name]= pd.read_csv (path,
                  delimiter='\t', 
                  names = ['ch1  R-bic', 'ch2 R-Tri 1' , 'ch3  L-Bic 2','ch4 L-Tri 3','ch5 R-Tri 4',
                           'ch6 R-Ham 5','ch7 L-Thi 6','ch8 L-Ham 7'])
for name,path in zip(Fn_S2A,file_path_S2A):
    d_S2_A[name]= pd.read_csv (path,
                  delimiter='\t', 
                  names = ['ch1  R-bic', 'ch2 R-Tri 1' , 'ch3  L-Bic 2','ch4 L-Tri 3','ch5 R-Tri 4',
                           'ch6 R-Ham 5','ch7 L-Thi 6','ch8 L-Ham 7'])
    
S2_N_Bowing = pd.DataFrame.from_dict(d_S2_N['S2_N_Bowing'])
S2_N_Clapping = pd.DataFrame.from_dict(d_S2_N['S2_N_Clapping'])
S2_N_Handshaking = pd.DataFrame.from_dict(d_S2_N['S2_N_Handshaking'])
S2_N_Hugging = pd.DataFrame.from_dict(d_S2_N['S2_N_Hugging'])
S2_N_Jumping = pd.DataFrame.from_dict(d_S2_N['S2_N_Jumping'])
S2_N_Running = pd.DataFrame.from_dict(d_S2_N['S2_N_Running'])
S2_N_Seating = pd.DataFrame.from_dict(d_S2_N['S2_N_Seating'])
S2_N_Standing = pd.DataFrame.from_dict(d_S2_N['S2_N_Standing'])
S2_N_Walking = pd.DataFrame.from_dict(d_S2_N['S2_N_Walking'])
S2_N_Waving = pd.DataFrame.from_dict(d_S2_N['S2_N_Waving'])



S2_A_Elbowing = pd.DataFrame.from_dict(d_S2_A["S2_A_Elbowing"])
S2_A_Frontkicking = pd.DataFrame.from_dict(d_S2_A["S2_A_Frontkicking"])
S2_A_Hamering = pd.DataFrame.from_dict(d_S2_A["S2_A_Hamering"])
S2_A_Headering = pd.DataFrame.from_dict(d_S2_A["S2_A_Headering"])
S2_A_Kneeing = pd.DataFrame.from_dict(d_S2_A["S2_A_Kneeing"])
S2_A_Pulling = pd.DataFrame.from_dict(d_S2_A["S2_A_Pulling"])
S2_A_Punching = pd.DataFrame.from_dict(d_S2_A["S2_A_Punching"])
S2_A_Pushing = pd.DataFrame.from_dict(d_S2_A["S2_A_Pushing"])
S2_A_Sidekicking = pd.DataFrame.from_dict(d_S2_A["S2_A_Sidekicking"])
S2_A_Slapping = pd.DataFrame.from_dict(d_S2_A["S2_A_Slapping"])
###########################################################################################
###########################################################################################

# %%
    

########################################################################################
########################################################################################

# %%
for path,name in zip(file_path_S3N,Fn_S3N):
    d_S3_N[name]= pd.read_csv (path,
                  delimiter='\t', 
                  names = ['ch1  R-bic', 'ch2 R-Tri 1' , 'ch3  L-Bic 2','ch4 L-Tri 3','ch5 R-Tri 4',
                           'ch6 R-Ham 5','ch7 L-Thi 6','ch8 L-Ham 7'])
  
for name,path in zip(Fn_S3A,file_path_S3A):
    d_S3_A[name]= pd.read_csv (path,
                  delimiter='\t', 
                  names = ['ch1  R-bic', 'ch2 R-Tri 1' , 'ch3  L-Bic 2','ch4 L-Tri 3','ch5 R-Tri 4',
                           'ch6 R-Ham 5','ch7 L-Thi 6','ch8 L-Ham 7'])

S3_N_Bowing = pd.DataFrame.from_dict(d_S3_N['S3_N_Bowing'])
S3_N_Clapping = pd.DataFrame.from_dict(d_S3_N['S3_N_Clapping'])
S3_N_Handshaking = pd.DataFrame.from_dict(d_S3_N['S3_N_Handshaking'])
S3_N_Hugging = pd.DataFrame.from_dict(d_S3_N['S3_N_Hugging'])
S3_N_Jumping = pd.DataFrame.from_dict(d_S3_N['S3_N_Jumping'])
S3_N_Running = pd.DataFrame.from_dict(d_S3_N['S3_N_Running'])
S3_N_Seating = pd.DataFrame.from_dict(d_S3_N['S3_N_Seating'])
S3_N_Standing = pd.DataFrame.from_dict(d_S3_N['S3_N_Standing'])
S3_N_Walking = pd.DataFrame.from_dict(d_S3_N['S3_N_Walking'])
S3_N_Waving = pd.DataFrame.from_dict(d_S3_N['S3_N_Waving'])

S3_A_Elbowing = pd.DataFrame.from_dict(d_S3_A["S3_A_Elbowing"])
S3_A_Frontkicking = pd.DataFrame.from_dict(d_S3_A["S3_A_Frontkicking"])
S3_A_Hamering = pd.DataFrame.from_dict(d_S3_A["S3_A_Hamering"])
S3_A_Headering = pd.DataFrame.from_dict(d_S3_A["S3_A_Headering"])
S3_A_Kneeing = pd.DataFrame.from_dict(d_S3_A["S3_A_Kneeing"])
S3_A_Pulling = pd.DataFrame.from_dict(d_S3_A["S3_A_Pulling"])
S3_A_Punching = pd.DataFrame.from_dict(d_S3_A["S3_A_Punching"])
S3_A_Pushing = pd.DataFrame.from_dict(d_S3_A["S3_A_Pushing"])
S3_A_Sidekicking = pd.DataFrame.from_dict(d_S3_A["S3_A_Sidekicking"])
S3_A_Slapping = pd.DataFrame.from_dict(d_S3_A["S3_A_Slapping"])

# %%
##########################################################################
##########################################################################

# %%
for path,name in zip(file_path_S4N,Fn_S4N):
    d_S4_N[name]= pd.read_csv (path,
                  delimiter='\t', 
                  names = ['ch1  R-bic', 'ch2 R-Tri 1' , 'ch3  L-Bic 2','ch4 L-Tri 3','ch5 R-Tri 4',
                           'ch6 R-Ham 5','ch7 L-Thi 6','ch8 L-Ham 7'])
  
for name,path in zip(Fn_S4A,file_path_S4A):
    d_S4_A[name]= pd.read_csv (path,
                  delimiter='\t', 
                  names = ['ch1  R-bic', 'ch2 R-Tri 1' , 'ch3  L-Bic 2','ch4 L-Tri 3','ch5 R-Tri 4',
                           'ch6 R-Ham 5','ch7 L-Thi 6','ch8 L-Ham 7'])

    
S4_N_Bowing = pd.DataFrame.from_dict(d_S4_N['S4_N_Bowing'])
S4_N_Clapping = pd.DataFrame.from_dict(d_S4_N['S4_N_Clapping'])
S4_N_Handshaking = pd.DataFrame.from_dict(d_S4_N['S4_N_Handshaking'])
S4_N_Hugging = pd.DataFrame.from_dict(d_S4_N['S4_N_Hugging'])
S4_N_Jumping = pd.DataFrame.from_dict(d_S4_N['S4_N_Jumping'])
S4_N_Running = pd.DataFrame.from_dict(d_S4_N['S4_N_Running'])
S4_N_Seating = pd.DataFrame.from_dict(d_S4_N['S4_N_Seating'])
S4_N_Standing = pd.DataFrame.from_dict(d_S4_N['S4_N_Standing'])
S4_N_Walking = pd.DataFrame.from_dict(d_S4_N['S4_N_Walking'])
S4_N_Waving = pd.DataFrame.from_dict(d_S4_N['S4_N_Waving'])

S4_A_Elbowing = pd.DataFrame.from_dict(d_S4_A["S4_A_Elbowing"])
S4_A_Frontkicking = pd.DataFrame.from_dict(d_S4_A["S4_A_Frontkicking"])
S4_A_Hamering = pd.DataFrame.from_dict(d_S4_A["S4_A_Hamering"])
S4_A_Headering = pd.DataFrame.from_dict(d_S4_A["S4_A_Headering"])
S4_A_Kneeing = pd.DataFrame.from_dict(d_S4_A["S4_A_Kneeing"])
S4_A_Pulling = pd.DataFrame.from_dict(d_S4_A["S4_A_Pulling"])
S4_A_Punching = pd.DataFrame.from_dict(d_S4_A["S4_A_Punching"])
S4_A_Pushing = pd.DataFrame.from_dict(d_S4_A["S4_A_Pushing"])
S4_A_Sidekicking = pd.DataFrame.from_dict(d_S4_A["S4_A_Sidekicking"])
S4_A_Slapping = pd.DataFrame.from_dict(d_S4_A["S4_A_Slapping"])

# %%
S1_N_Bowing ['Title']= ' S1_N_Bowing '
S1_N_Clapping ['Title']= ' S1_N_Clapping '
S1_N_Handshaking ['Title']= ' S1_N_Handshaking '
S1_N_Hugging ['Title']= ' S1_N_Hugging '
S1_N_Jumping ['Title']= ' S1_N_Jumping '
S1_N_Running ['Title']= ' S1_N_Running '
S1_N_Seating ['Title']= ' S1_N_Seating '
S1_N_Standing ['Title']= ' S1_N_Standing '
S1_N_Walking ['Title']= ' S1_N_Walking '
S1_N_Waving ['Title']= ' S1_N_Waving '

S2_N_Bowing ['Title']= ' S2_N_Bowing '
S2_N_Clapping ['Title']= ' S2_N_Clapping '
S2_N_Handshaking ['Title']= ' S2_N_Handshaking '
S2_N_Hugging ['Title']= ' S2_N_Hugging '
S2_N_Jumping ['Title']= ' S2_N_Jumping '
S2_N_Running ['Title']= ' S2_N_Running '
S2_N_Seating ['Title']= ' S2_N_Seating '
S2_N_Standing ['Title']= ' S2_N_Standing '
S2_N_Walking ['Title']= ' S2_N_Walking '
S2_N_Waving ['Title']= ' S2_N_Waving '
 
S3_N_Bowing ['Title']= ' S3_N_Bowing '
S3_N_Clapping ['Title']= ' S3_N_Clapping '
S3_N_Handshaking ['Title']= ' S3_N_Handshaking '
S3_N_Hugging ['Title']= ' S3_N_Hugging '
S3_N_Jumping ['Title']= ' S3_N_Jumping '
S3_N_Running ['Title']= ' S3_N_Running '
S3_N_Seating ['Title']= ' S3_N_Seating '
S3_N_Standing ['Title']= ' S3_N_Standing '
S3_N_Walking ['Title']= ' S3_N_Walking '
S3_N_Waving ['Title']= ' S3_N_Waving '
 
S4_N_Bowing ['Title']= ' S4_N_Bowing '
S4_N_Clapping ['Title']= ' S4_N_Clapping '
S4_N_Handshaking ['Title']= ' S4_N_Handshaking '
S4_N_Hugging ['Title']= ' S4_N_Hugging '
S4_N_Jumping ['Title']= ' S4_N_Jumping '
S4_N_Running ['Title']= ' S4_N_Running '
S4_N_Seating ['Title']= ' S4_N_Seating '
S4_N_Standing ['Title']= ' S4_N_Standing '
S4_N_Walking ['Title']= ' S4_N_Walking '
S4_N_Waving ['Title']= ' S4_N_Waving '	
 
S1_A_Elbowing ['Title']= ' S1_A_Elbowing '
S1_A_Frontkicking ['Title']= ' S1_A_Frontkicking '
S1_A_Hamering ['Title']= ' S1_A_Hamering '
S1_A_Headering ['Title']= ' S1_A_Headering '
S1_A_Kneeing ['Title']= ' S1_A_Kneeing '
S1_A_Pulling ['Title']= ' S1_A_Pulling '
S1_A_Punching ['Title']= ' S1_A_Punching '
S1_A_Pushing ['Title']= ' S1_A_Pushing '
S1_A_Sidekicking ['Title']= ' S1_A_Sidekicking '
S1_A_Slapping ['Title']= ' S1_A_Slapping '

S2_A_Elbowing ['Title']= ' S2_A_Elbowing '
S2_A_Frontkicking ['Title']= ' S2_A_Frontkicking '
S2_A_Hamering ['Title']= ' S2_A_Hamering '
S2_A_Headering ['Title']= ' S2_A_Headering '
S2_A_Kneeing ['Title']= ' S2_A_Kneeing '
S2_A_Pulling ['Title']= ' S2_A_Pulling '
S2_A_Punching ['Title']= ' S2_A_Punching '
S2_A_Pushing ['Title']= ' S2_A_Pushing '
S2_A_Sidekicking ['Title']= ' S2_A_Sidekicking '
S2_A_Slapping ['Title']= ' S2_A_Slapping ' 

S3_A_Elbowing ['Title']= ' S3_A_Elbowing '
S3_A_Frontkicking ['Title']= ' S3_A_Frontkicking '
S3_A_Hamering ['Title']= ' S3_A_Hamering '
S3_A_Headering ['Title']= ' S3_A_Headering '
S3_A_Kneeing ['Title']= ' S3_A_Kneeing '
S3_A_Pulling ['Title']= ' S3_A_Pulling '
S3_A_Punching ['Title']= ' S3_A_Punching '
S3_A_Pushing ['Title']= ' S3_A_Pushing '
S3_A_Sidekicking ['Title']= ' S3_A_Sidekicking '
S3_A_Slapping ['Title']= ' S3_A_Slapping ' 

S4_A_Elbowing ['Title']= ' S4_A_Elbowing '
S4_A_Frontkicking ['Title']= ' S4_A_Frontkicking '
S4_A_Hamering ['Title']= ' S4_A_Hamering '
S4_A_Headering ['Title']= ' S4_A_Headering '
S4_A_Kneeing ['Title']= ' S4_A_Kneeing '
S4_A_Pulling ['Title']= ' S4_A_Pulling '
S4_A_Punching ['Title']= ' S4_A_Punching '
S4_A_Pushing ['Title']= ' S4_A_Pushing '
S4_A_Sidekicking ['Title']= ' S4_A_Sidekicking '
S4_A_Slapping ['Title']= ' S4_A_Slapping '

# %%
S1_N = pd.concat([S1_N_Bowing,S1_N_Clapping,S1_N_Handshaking,
                  S1_N_Hugging,S1_N_Jumping,S1_N_Running,       
                  S1_N_Seating,S1_N_Standing,S1_N_Walking,S1_N_Waving])

S2_N = pd.concat([S2_N_Bowing,S2_N_Clapping,S2_N_Handshaking,
                  S2_N_Hugging,S2_N_Jumping,S2_N_Running,        
                  S2_N_Seating,S2_N_Standing,S2_N_Walking,S2_N_Waving])

S3_N = pd.concat([S3_N_Bowing,S3_N_Clapping,S3_N_Handshaking,
                  S3_N_Hugging,S3_N_Jumping,S3_N_Running,        
                  S3_N_Seating,S3_N_Standing,S3_N_Walking,S3_N_Waving])

S4_N = pd.concat([S4_N_Bowing,S4_N_Clapping,S4_N_Handshaking,
                  S4_N_Hugging,S4_N_Jumping,S4_N_Running,        
                  S4_N_Seating,S4_N_Standing,S4_N_Walking,S4_N_Waving])
    
S1_A = pd.concat([S1_A_Elbowing,S1_A_Frontkicking,S1_A_Hamering,
                  S1_A_Headering,S1_A_Kneeing,S1_A_Pulling,
                  S1_A_Punching,S1_A_Pushing,S1_A_Sidekicking,S1_A_Slapping])

S2_A = pd.concat([S2_A_Elbowing,S2_A_Frontkicking,S2_A_Hamering,
                  S2_A_Headering,S2_A_Kneeing,S2_A_Pulling,
                  S2_A_Punching,S2_A_Pushing,S2_A_Sidekicking,S2_A_Slapping])
    
S3_A = pd.concat([S3_A_Elbowing,S3_A_Frontkicking,S3_A_Hamering,
                  S3_A_Headering,S3_A_Kneeing,S3_A_Pulling,
                  S3_A_Punching,S3_A_Pushing,S3_A_Sidekicking,S3_A_Slapping])
    
S4_A = pd.concat([S4_A_Elbowing,S4_A_Frontkicking,S4_A_Hamering,
                  S4_A_Headering,S4_A_Kneeing,S4_A_Pulling,
                  S4_A_Punching,S4_A_Pushing,S4_A_Sidekicking,S4_A_Slapping])

# %%
SN = pd.concat([S1_N,S2_N,S3_N,S4_N])
SA = pd.concat([S1_A,S2_A,S3_A,S4_A])

# %%
SN.to_csv('SUB_Normal')
SA.to_csv('SUB_Aggressive')
